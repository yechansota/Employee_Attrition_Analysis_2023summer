# %% [markdown]
# <a href="https://colab.research.google.com/github/yechansota/Employee_Attrition_Analysis_2023summer/blob/main/Project_(1)_Employee_Attrition_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📊Project: Employee Attrition Analysis
# ---
# > **Index**
#
# * Business Understanding🔍
# * Data Understanding🪡
# * Data Preparation🧶
# * Modeling🧵
# * Evaluation 🪢
# * ML Prediction 🧊
# * Conclusion 👔

# %% [markdown]
# ## **Business Understanding**
# ---
# >**Scenario**🎫
#
# In recent years, Company A has experienced **high employee attrition**, prompting them to form a task force in collaboration with HR. The task force, comprised of HR professionals, people analysts, and data scientists, aims to analyze the current situation and identify factors contributing to attrition.
#
# With valuable insights from the analysis, the task force's primary objective is to develop a **customized retention program**. They will closely collaborate with HR professionals to implement effective strategies to address the attrition challenge.
#
# Through this concerted effort, Company A seeks to **build a stronger and stable workforce, fostering a positive work environment** for all employees and securing a brighter future for the company's success.
#
# **About the Dataset**: This is a fictional dataset created by IBM data scientists, delving into factors influencing employee turnover. Metrics include employee's demographic information and various job satisfaction ratings.

# %% [markdown]
# ##  **Data Understanding**
# ---
#
# > **Data Description**
#
#
# |Variables||||||
# |:---:|:---:|:---:|:---:|:---:|:---:|
# |Age|Attrition|BusinessTravel|DailyRate|Department|DistanceFromHome|
# |Education|EducationField|EmployeeCount|EmployeeNumber|EnvironmentSatisfaction|Gender|
# |HourlyRate|JobInvolvement|JobLevel|JobRole|JobSatisfaction|MaritalStatus|
# |MonthlyIncome|MonthlyRate|NumCompaniesWorked|Over18|OverTime|PercentSalaryHike|
# |PerformanceRating|RelationshipSatisfaction|StandardHours|StockOptionLevel|TotalWorkingYears|TrainingTimesLastYear|
# |WorkLifeBalance|YearsAtCompany|YearsInCurrentRole|YearsSinceLastPromotion|YearsWithCurrManager|

# %% [markdown]
# > **Data Dictionary**
# ---
# *Age*: Age of the employee.
#
# *Attrition*
# : Whether the employee left the company or not (Yes: Left, No: Stayed).
#
# *BusinessTravel*
# : Frequency of business travel for the employee (Non-Travel,
# Travel_Rarely, Travel_Frequently).
#
# *DailyRate*
# : Daily rate of the employee's pay.
#
# *Department*
# : Department in which the employee works.
#
# *DistanceFromHome*
# : Distance from the employee's home to the workplace.
#
# *Education*
# : Education level of the employee (1: 'Below College', 2: 'College',
# 3: 'Bachelor', 4: 'Master', 5: 'Doctor').
#
# *EducationField*
# : Field of study of the employee.
#
# *EmployeeCount*
# : A count of the employees. Likely a redundant field if all values
# are 1.
#
# *EmployeeNumber*
# : Employee ID number.
#
# *EnvironmentSatisfaction*
# : Employee's rating of their work environment (1: 'Low',
# 2: 'Medium', 3: 'High', 4: 'Very High').
#
# *Gender*
# : Employee's gender (Male, Female).
#
# *HourlyRate*
# : Hourly rate of the employee's pay.
#
# *JobInvolvement*
# : Employee's rating of their job involvement (1: 'Low', 2:
# 'Medium', 3: 'High', 4: 'Very High').
#
# *JobLevel*
# : Level of the employee's job role.
#
# *JobRole*
# : Title of the employee's job role.
#
# *JobSatisfaction*
# : Employee's rating of their job satisfaction (1: 'Low', 2:
# 'Medium', 3: 'High', 4: 'Very High').
#
# *MaritalStatus*: Marital status of the employee (Single, Married, Divorced).
#
# *MonthlyIncome*: Monthly income of the employee.
#
# *MonthlyRate*
# : Monthly rate of the employee's pay.
#
# *NumCompaniesWorked*
# : Number of companies the employee has worked for.
#
# *Over18*
# : Whether the employee is over 18 years of age or not (Yes, No).
#
# *OverTime*
# : Whether the employee works overtime or not (Yes: Works overtime, No:
# Does not work overtime).
#
# *PercentSalaryHike*
# : Percent increase in salary from last year.
#
# *PerformanceRating*: Employee's performance rating (1: 'Low', 2: 'Good', 3:
# 'Excellent', 4: 'Outstanding').
#
# *RelationshipSatisfaction*
# : Employee's rating of their relationship satisfaction
# (1: 'Low', 2: 'Medium', 3: 'High', 4: 'Very High').
#
# *StandardHours
# : Standard hours the employee is expected to work.
#
# *StockOptionLevel*
# : Level of the employee's stock option.
#
# *TotalWorkingYears*
# : Total number of years the employee has worked.
#
# *TrainingTimesLastYear*
# : Number of times training was conducted for this employee
# last year.
#
# *WorkLifeBalance*
# : Employee's rating of their work-life balance (1: 'Bad', 2:
# 'Good', 3: 'Better', 4: 'Best').
#
# *YearsAtCompany*
# : Number of years the employee has worked at the company.
#
# *YearsInCurrentRole*
# : Number of years the employee has worked in their current
# role.
#
# *YearsSinceLastPromotion*
# : Number of years since the employee was last promoted.
#
# *YearsWithCurrManager*
# : Number of years the employee has worked with their
# current manager.
#
# ---

# %%
# ▶ Data read
import warnings
warnings.filterwarnings('ignore')
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
df = pd.read_csv('/content/Job_Attrition_IBM.csv')
df.head(5)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# ...

# %% [markdown]
# ## **Problem Statement**
# ---
# > **Identify Circumstances**
#
# ```
# ▶ High Attrition Rate
# ▶ Loss Talent Pipeline
# ▶ Bad Business Operation
# ```
#
# > **Define Solution**
#
# ```
# ▶Identify employees who may leave the company A and develop retention program  to encourage them to stay.
# ▶ Step 1 🥉
#  - Data Preprocessing and Explore Employee Attrition Data
# ▶ Step 2 🥈
#  - Explore data to Establish and Evaluate Hypothesis
# ▶ Step 3 🥇
#  - Utilize Machine Learning to predict Potential Employee Attrition
#
# ```
#
# > **Goal**
#
# ```
# ▶ Resolve High Attrition
# ▶ Retain Key Talents
# ▶ Better Operate Business
# ```
#
# > **Evaluation**
#
# ```
# ▶ Monitor the Performance of the Retention Program
# ▶ Execute Exit Interviews and Develop the Program Based on the Feedback
# ```
#
# > **Apply**
#
# ```
# ▶ Create Monthly Data Mart to input the model
# ▶ Export the monthly target and monitor the retention program
# ```

# %% [markdown]
# ## **☝🏽Step 1**
# **┗ Explore Employee Attrition Data**
# ---

# %% [markdown]
# ### Data Processing
# ---
#   (1) Data Shape
#
#   (2) Data type
#
#   (3) Null
#
#   (4) Outlier

# %%
#Explore and identify datasets to cleansing data (null and outliers)
print('df', df.shape)
df.info()
print(df.isnull().sum())
# Out:
# df (1470, 35)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ### Explore Data
# ---

# %%
# Transformatting Attrition rate from object to value 1:0
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df.head(2)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# ...

# %%
df['Attrition'] = np.where(df['Attrition']== 'Yes', 1, 0)
df['Attrition'].value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
df['Attrition'].value_counts() #Employee Attrition 16%
237 / (237+1233)
# Out:
# 0.16122448979591836

# %%
# Employee Attrition by Age
df['Age_gp'] = np.where (df['Age'] <= 30, 'Below30',
                           np.where(df['Age'] <= 40, 'Between30-40', 'Above40'))
df[['Age','Age_gp']]
# Out:
#       Age        Age_gp
# 0      41       Above40
# 1      49       Above40
# 2      37  Between30-40
# 3      33  Between30-40
# 4      27       Below30
# ...   ...           ...
# 1465   36  Between30-40
# 1466   39  Between30-40
# 1467   27       Below30
# 1468   49       Above40
# 1469   34  Between30-40
#
# [1470 rows x 2 columns]

# %%
df_gp = df.groupby('Age_gp')['Attrition'].agg(['count','sum'])
df_gp['ratio'] = round((df_gp['sum'] / df_gp['count']) * 100, 1)
df_gp
# Out:
#               count  sum  ratio
# Age_gp
# Above40         465   52   11.2
# Below30         386  100   25.9
# Between30-40    619   85   13.7

# %%
age_description = df['Age'].describe()
print(age_description)
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %%
# Employee Attrition by Gender (Female: 14.8% | Male 17%)
df_gp = df.groupby('Gender')['Attrition'].agg(['count','sum'])
df_gp['ratio'] = round((df_gp['sum'] / df_gp['count']) * 100, 1)
df_gp
# Out:
#         count  sum  ratio
# Gender
# Female    588   87   14.8
# Male      882  150   17.0

# %%
# Single are more likely to leave the company A compare to other groups.
df_gp = df.groupby('MaritalStatus')['Attrition'].agg(['count','sum'])
df_gp['ratio'] = round((df_gp['sum'] / df_gp['count']) * 100, 1)
df_gp
# Out:
#                count  sum  ratio
# MaritalStatus
# Divorced         327   33   10.1
# Married          673   84   12.5
# Single           470  120   25.5

# %%
# Employee Attrition by Department (HR 19% | R&D 13.8% | Sales 20.6%)
df_gp = df.groupby('Department')['Attrition'].agg(['count','sum'])
df_gp['ratio'] = round((df_gp['sum'] / df_gp['count']) * 100, 1)
df_gp
# Out:
#                         count  sum  ratio
# Department
# Human Resources            63   12   19.0
# Research & Development    961  133   13.8
# Sales                     446   92   20.6

# %%
df_gp = df.groupby('JobLevel')['Attrition'].agg(['count'])
df_gp
# Out:
#           count
# JobLevel
# 1           543
# 2           534
# 3           218
# 4           106
# 5            69

# %%
df_gp = df.groupby('Department')['Attrition'].agg(['count'])
df_gp
# Out:
#                         count
# Department
# Human Resources            63
# Research & Development    961
# Sales                     446

# %% [markdown]
# > **Insight**
# ---
# - Lower job levels (1 and 2) generally have higher attrition rates across all departments, possibly due to employees seeking better opportunities or further education early in their careers.
#
# - The Sales department shows a notably high attrition rate at Job Level 1, possibly linked to factors like job stress, compensation, or job demands.
#
# - The Research & Development department has lower attrition rates, particularly at higher job levels (4 and 5).
#
# - The Human Resources department has high attrition rates at Job Levels 1 and 3, but none at Levels 2, 4, and 5, potentially due to fewer employees at these levels, causing larger rate fluctuations.

# %% [markdown]
# ## **✌🏽Step 2**
# **┗Hypothesis Testing**
# ---

# %% [markdown]
# ### Hypothesis (1)
# ---
#
# * "High job satisfaction may not always result in low turnover rates, as RelationshipSatisfaction is one of factors."

# %%
df[['JobSatisfaction', 'RelationshipSatisfaction', 'Attrition']].head(5)
# Out:
#    JobSatisfaction  RelationshipSatisfaction  Attrition
# 0                4                         1          1
# 1                2                         4          0
# 2                3                         2          1
# 3                3                         3          0
# 4                2                         4          0

# %%
df_gp = df.groupby(['JobSatisfaction'])['Attrition'].agg(['count','sum'])
df_gp['ratio'] = round((df_gp['sum'] / df_gp['count']) * 100, 1)
df_gp
# Out:
#                  count  sum  ratio
# JobSatisfaction
# 1                  289   66   22.8
# 2                  280   46   16.4
# 3                  442   73   16.5
# 4                  459   52   11.3

# %%
# The lower job satisfaction come out, attrition rate is be higher. (JobSat | Attrition),
# However Employees with high job satisfaction seem to be less affected by the turnover rate depending on the personnel relationship,
# whereas employees with low job satisfaction tend to increase the turnover rate as the personnel relationship is worse

df_gp = df.groupby(['JobSatisfaction','RelationshipSatisfaction'])['Attrition'].agg(['count','sum'])
df_gp['ratio'] = round((df_gp['sum'] / df_gp['count']) * 100, 1)
df_gp
# Out:
#                                           count  sum  ratio
# JobSatisfaction RelationshipSatisfaction
# 1               1                            54   16   29.6
#                 2                            57   15   26.3
#                 3                            91   22   24.2
#                 4                            87   13   14.9
# 2               1                            53   15   28.3
#                 2                            57    8   14.0
#                 3                            81   13   16.0
#                 4                            89   10   11.2
# 3               1                            85   16   18.8
#                 2                            94   11   11.7
#                 3                           133   19   14.3
#                 4                           130   27   20.8
# 4               1                            84   10   11.9
#                 2                            95   11   11.6
# ...

# %% [markdown]
# ### Hypothesis (2)
# ---
#
# * The high attrition rate may be different depending on the department and job level.

# %%
df_gp = df.groupby(['JobLevel'])['Attrition'].agg(['count','sum'])
df_gp['ratio'] = round((df_gp['sum'] / df_gp['count']) * 100, 1)
df_gp
# Out:
#           count  sum  ratio
# JobLevel
# 1           543  143   26.3
# 2           534   52    9.7
# 3           218   32   14.7
# 4           106    5    4.7
# 5            69    5    7.2

# %%
# Job Level 1 has the high attrition rate overall, but the HR and Sales department had a significiant rate compare to R&D department
# Once people got in jobLevel 4, the attrition rate decreases.
df_gp = df.groupby(['JobLevel','Department'])['Attrition'].agg(['count','sum'])
df_gp['ratio'] = round((df_gp['sum'] / df_gp['count']) * 100, 1)
df_gp
# Out:
#                                  count  sum  ratio
# JobLevel Department
# 1        Human Resources             0  0.0    NaN
#          Research & Development      0  0.0    NaN
#          Sales                       0  0.0    NaN
# 2        Human Resources             0  0.0    NaN
#          Research & Development      0  0.0    NaN
#          Sales                       0  0.0    NaN
# 3        Human Resources             0  0.0    NaN
#          Research & Development      0  0.0    NaN
#          Sales                       0  0.0    NaN
# 4        Human Resources             0  0.0    NaN
#          Research & Development      0  0.0    NaN
#          Sales                       0  0.0    NaN
# 5        Human Resources             0  0.0    NaN
#          Research & Development      0  0.0    NaN
#          Sales                       0  0.0    NaN

# %%
import numpy as np
from google.colab import autoviz

def value_plot(df, y, sort_ascending=False, figscale=1):
  from matplotlib import pyplot as plt
  figsize = (15 * figscale, 4 * figscale)
  if sort_ascending:
    df = df.sort_values(y).reset_index(drop=True)
  _, ax = plt.subplots(figsize=figsize)
  df[y].plot(kind='line')
  plt.title(y)
  ax.spines[['top', 'right',]].set_visible(False)
  plt.tight_layout()
  return autoviz.MplChart.from_current_mpl_state()

chart = value_plot(df_gp, *['ratio'], **{})
chart
# Out:
# <img src="...

# %% [markdown]
# > Insight
# * According to HR data, the job levels with the highest attrition rates are level 1 and level 3, both at a rate of 30.
# * However, the attrition rate in R&D is also significant, despite having the largest number of total hires.

# %% [markdown]
# ### Hypothesis (3)
# ---
#
# * "If employees hold the same position at Company A for multiple years, the rate of employee turnover is likely to be high.""

# %%
#If employees hold the same position at Company A for couple of years, the rate of employee turnover is likely to be high.
df['Role_Company'] = df['YearsInCurrentRole'] / df['YearsAtCompany']
df['Role_Company'].fillna(0, inplace =True)

# %%
# ▶ Explore the employee attrition rate distribution
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use(['dark_background'])
sns.distplot(df['Role_Company'])
plt.title('Density by Role in Work and Years of Company')
plt.show()

# %%
# Binning for 3 groups
import numpy as np
df['Role_Company_gp'] = np.where (df['Role_Company'] <= 0.4, 'Below0.4',
                           np.where(df['Role_Company'] <= 0.8, 'Between0.4-0.8', 'Over0.8'))

df[['Role_Company','Role_Company_gp']]
# Out:
#       Role_Company Role_Company_gp
# 0         0.666667  Between0.4-0.8
# 1         0.700000  Between0.4-0.8
# 2         0.000000        Below0.4
# 3         0.875000         Over0.8
# 4         1.000000         Over0.8
# ...            ...             ...
# 1465      0.400000        Below0.4
# 1466      1.000000         Over0.8
# 1467      0.333333        Below0.4
# 1468      0.666667  Between0.4-0.8
# 1469      0.750000  Between0.4-0.8
#
# [1470 rows x 2 columns]

# %%
# ▶ If employees hold the same position at Company A for multiple years, the turnover rate is actaculy low.
df_gp = df.groupby('Role_Company_gp')['Attrition'].agg(['count', 'sum'])
df_gp['ratio'] = round((df_gp['sum'] / df_gp['count']) * 100, 1)
df_gp
# Out:
#                  count  sum  ratio
# Role_Company_gp
# Below0.4           454  103   22.7
# Between0.4-0.8     621   81   13.0
# Over0.8            395   53   13.4

# %% [markdown]
# > Insight
# * If employees stay in the same position at Company A for several years, the turnover rate is actually low.

# %% [markdown]
# ### Hypothesis (4)
# ---
#
# * "If there are employees who overwork but receive a high percentage increase in salary, the rate of employee attrition will be low."

# %%
# Analyze how the attrition rate and overtime are related.
# People are more likely to leave the company if they work overtime
df_gp = df.groupby('OverTime')['Attrition'].agg(['count', 'sum'])
df_gp['ratio'] = round((df_gp['sum'] / df_gp['count']) * 100, 1)
df_gp
# Out:
#           count  sum  ratio
# OverTime
# No         1054  110   10.4
# Yes         416  127   30.5

# %%
# There is no strong correlation between not working overtime and receiving a salary increase as a reason for leaving the company.
df_gp = df.groupby(['OverTime', 'PercentSalaryHike'])['Attrition'].agg(['count', 'sum'])
df_gp['ratio'] = round((df_gp['sum'] / df_gp['count']) * 100, 1)
df_gp
# Out:
#                             count  sum  ratio
# OverTime PercentSalaryHike
# No       11                   149   19   12.8
#          12                   139   18   12.9
#          13                   144   14    9.7
#          14                   145    8    5.5
#          15                    80   12   15.0
#          16                    55    8   14.5
#          17                    66    9   13.6
#          18                    60    5    8.3
#          19                    55    3    5.5
#          20                    40    4   10.0
#          21                    36    2    5.6
#          22                    41    6   14.6
#          23                    19    1    5.3
#          24                    12    1    8.3
#          25                    13    0    0.0
# Yes      11                    61   22   36.1
#          12                    59   15   25.4
#          13                    65   20   30.8
#          14                    56   16   28.6
# ...

# %%
df_gp_plot = df_gp.reset_index()
df_gp_plot = df_gp_plot[df_gp_plot['OverTime']=='Yes']
df_gp_plot
# Out:
#    OverTime  PercentSalaryHike  count  sum  ratio
# 15      Yes                 11     61   22   36.1
# 16      Yes                 12     59   15   25.4
# 17      Yes                 13     65   20   30.8
# 18      Yes                 14     56   16   28.6
# 19      Yes                 15     21    6   28.6
# 20      Yes                 16     23    6   26.1
# 21      Yes                 17     16    5   31.2
# 22      Yes                 18     29    8   27.6
# 23      Yes                 19     21    6   28.6
# 24      Yes                 20     15    3   20.0
# 25      Yes                 21     12    3   25.0
# 26      Yes                 22     15    6   40.0
# 27      Yes                 23      9    5   55.6
# 28      Yes                 24      9    5   55.6
# 29      Yes                 25      5    1   20.0

# %%
def value_plot(df, y, sort_ascending=False, figscale=1):
    from matplotlib import pyplot as plt

    figsize = (8 * figscale, 4 * figscale)

    if sort_ascending:
        df = df.sort_values(y).reset_index(drop=True)

    _, ax = plt.subplots(figsize=figsize)

    df[y].plot(kind='line', ax=ax)

    for i, value in enumerate(df[y]):
        ax.annotate(f'{value:.2f}', (df.index[i], value), fontsize=8, ha='center', va='bottom')


    if y == 'ratio':
        plt.title('Yes-Overtime by Salary Hike')
    else:
        plt.title(y)

    ax.spines[['top', 'right',]].set_visible(False)
    plt.tight_layout()
    return autoviz.MplChart.from_current_mpl_state()

chart = value_plot(_df_3, *['ratio'], **{})
chart
# Out:
# <img src="...

# %%
df_gp_plot = df_gp.reset_index()
df_gp_plot = df_gp_plot[df_gp_plot['OverTime']=='No']
df_gp_plot
# Out:
#    OverTime  PercentSalaryHike  count  sum  ratio
# 0        No                 11    149   19   12.8
# 1        No                 12    139   18   12.9
# 2        No                 13    144   14    9.7
# 3        No                 14    145    8    5.5
# 4        No                 15     80   12   15.0
# 5        No                 16     55    8   14.5
# 6        No                 17     66    9   13.6
# 7        No                 18     60    5    8.3
# 8        No                 19     55    3    5.5
# 9        No                 20     40    4   10.0
# 10       No                 21     36    2    5.6
# 11       No                 22     41    6   14.6
# 12       No                 23     19    1    5.3
# 13       No                 24     12    1    8.3
# 14       No                 25     13    0    0.0

# %%
def value_plot(df, y, sort_ascending=False, figscale=1):

    figsize = (8 * figscale, 4 * figscale)

    if sort_ascending:
        df = df.sort_values(y).reset_index(drop=True)

    _, ax = plt.subplots(figsize=figsize)
    df[y].plot(kind='line')

    for i, value in enumerate(df[y]):
        ax.annotate(f'{value:.2f}', (i, value), fontsize=8, ha='right')

    if y == 'ratio':
        plt.title('No-Overtime with Salary Hike')
    else:
        plt.title(y)

    ax.spines[['top', 'right',]].set_visible(False)
    plt.tight_layout()
    return autoviz.MplChart.from_current_mpl_state()

chart = value_plot(df_gp_plot, *['ratio'], **{})
chart
# Out:
# <img src="...

# %%
plt.style.use(['dark_background'])
plt.title('Overtime ratio by Percent SalaryHike')
plt.xlabel('Percent Salary Hike')
plt.ylabel('Overtime Ratio')

bars = plt.bar(df_gp_plot['PercentSalaryHike'], df_gp_plot['ratio'])

# Annotate each bar with its height value
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height + 0.01, f'{height:.2f}',
             ha='center', va='bottom', color='white', fontsize=8)

plt.show()

# %% [markdown]
# > Insight
# * It is not necessarily true that not working overtime is linked to receiving a salary increase as a reason for leaving the company due to a salary hike.

# %% [markdown]
# ## **👌🏽Session 3**
# **┗ Apply Machine Learning to Predict the Employee Attrition Rate**
# ---

# %% [markdown]
# ## Prepocessing the Data Modeling
# ---

# %%
# ▶ Define numerical and categorical value from the datamart
numeric_list=[]
categoical_list=[]

for i in df.columns :
  if df[i].dtypes == 'O' :
    categoical_list.append(i)
  else :
    numeric_list.append(i)

print("categoical_list :", categoical_list)
print("numeric_list :", numeric_list)
# Out:
# categoical_list : ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime', 'Age_gp', 'Role_Company_gp']
# numeric_list : ['Age', 'Attrition', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Role_Company']

# %% [markdown]
# **Categoical_list** : ['BusinessTravel', 'Department',
# 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime', '*Age_gp*', '*Role_Company_gp*']
#
# **Numeric_list** : ['Age', '*Attrition*', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Role_Company']

# %%
#imports machine learning alogrithm used for classfication task
#import various ML functions
# Before starting to model, it's important to distinguish between variables X and Y.
# This will help ensure accuracy and precision when analyzing and interpreting the data.
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

X=df.drop(['Attrition', 'Age_gp', 'Role_Company_gp', 'Role_Company'], axis=1)
Y=df['Attrition']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, stratify=Y)

print(x_train.shape)
print(y_train.shape)

print(x_test.shape)
print(y_test.shape)
# Out:
# (1029, 34)
# (1029,)
# (441, 34)
# (441,)

# %%
from sklearn.preprocessing import LabelEncoder

for col in categoical_list:
    if col in x_train.columns and col in x_test.columns:
        print(col)
        le = LabelEncoder()
        le.fit(list(x_train[col].values) + list(x_test[col].values))
        x_train[col] = le.transform(x_train[col])
        x_test[col] = le.transform(x_test[col])
    else:
        print(f"Column {col} not found in both x_train and x_test!")
# Out:
# BusinessTravel
# Department
# EducationField
# Gender
# JobRole
# MaritalStatus
# Over18
# OverTime
# Column Age_gp not found in both x_train and x_test!
# Column Role_Company_gp not found in both x_train and x_test!

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# Check if 'Age_gp' column exists in the DataFrame before dropping it
if 'Age_gp' in df.columns:
    X = df.drop(['Attrition', 'Age_gp', 'Role_Company_gp', 'Role_Company'], axis=1)
else:
    X = df.drop(['Attrition', 'Role_Company_gp', 'Role_Company'], axis=1)

Y = df['Attrition']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, stratify=Y)

# %%
try:
    categoical_list.remove('Age_gp')
except ValueError:
    pass

try:
    categoical_list.remove('Role_Company_gp')
except ValueError:
    pass

# %%
x_test[categoical_list].head(10)
# Out:
#       BusinessTravel  Department  EducationField  Gender  JobRole  \
# 1127               2           1               5       1        6
# 1215               1           1               3       1        6
# 399                2           1               1       1        2
# 668                2           1               3       0        6
# 359                1           2               3       1        7
# 239                2           1               1       1        2
# 285                2           1               1       0        6
# 1394               2           1               1       1        4
# 955                2           1               3       0        3
# 882                2           1               5       0        4
#
#       MaritalStatus  Over18  OverTime
# 1127              1       0         0
# 1215              2       0         1
# 399               1       0         0
# 668               0       0         0
# 359               1       0         0
# ...

# %% [markdown]
# ###  Model Evaluation
# ---

# %%
from sklearn.metrics import classification_report
rfc = RandomForestClassifier(random_state = 123456, max_depth=3, n_estimators=125)
# The random forest model will produce the same results whenever the code is executed with the same random_state value.
# By limiting the depth of the trees, max_depth helps the model generalize better and produce more accurate predictions on unseen data.
# This will be composed of 125 decision trees.
rfc.fit(x_train, y_train)

# 예측

y_pred_train = rfc.predict(x_train)
y_pred_test = rfc.predict(x_test)

print(classification_report(y_train, y_pred_train))
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       863
#            1       1.00      0.02      0.04       166
#
#     accuracy                           0.84      1029
#    macro avg       0.92      0.51      0.47      1029
# weighted avg       0.87      0.84      0.77      1029
#
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       370
#            1       1.00      0.03      0.05        71
#
#     accuracy                           0.84       441
#    macro avg       0.92      0.51      0.48       441
# weighted avg       0.87      0.84      0.78       441

# %%
y_pred_train
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
pd.Series(y_pred_test).value_counts()
# The model has classified the majority of the test samples as class 0 (negative class)
# only a very small number of samples as class 1 (positive class) based on the chosen threshold.
# --> This suggests that the model is more confident in assigning these samples to the negative class (class 0) based on their corresponding predicted probabilities.
# Out:
# 0    439
# 1      2
# dtype: int64

# %%
from sklearn.metrics import classification_report

y_pred_train = rfc.predict_proba(x_train)[:, 1]
# If the probability is greater than or equal to 0.3,
# It sets the corresponding value in y_pred_train to 1, representing a positive prediction.
for i in range(0,len(y_pred_train)):
    if y_pred_train[i]>=.3:
       y_pred_train[i]=1
    else:
       y_pred_train[i]=0

y_pred_test = rfc.predict_proba(x_test)[:, 1]
for i in range(0,len(y_pred_test)):
    if y_pred_test[i]>=.3:
       y_pred_test[i]=1
    else:
       y_pred_test[i]=0

print(classification_report(y_train, y_pred_train))
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92       863
#            1       0.67      0.27      0.38       166
#
#     accuracy                           0.86      1029
#    macro avg       0.77      0.62      0.65      1029
# weighted avg       0.84      0.86      0.83      1029
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91       370
#            1       0.54      0.30      0.38        71
#
#     accuracy                           0.85       441
#    macro avg       0.71      0.62      0.65       441
# weighted avg       0.82      0.85      0.83       441

# %%
pd.Series(y_pred_test).value_counts()
#Calculate  value=1/value=0
# Out:
# 0.0    402
# 1.0     39
# dtype: int64

# %%
39/402
# Out:
# 0.09701492537313433

# %%
# Optimizing relevant variables prevents overfitting in both training and new, unseen data.
# The result of train/test indicate the model perform well in general
from sklearn.metrics import roc_auc_score

y_pred_train_proba = rfc.predict_proba(x_train)[:, 1]
y_pred_test_proba = rfc.predict_proba(x_test)[:, 1]


roc_score_train = roc_auc_score(y_train, y_pred_train_proba)
roc_score_test = roc_auc_score(y_test, y_pred_test_proba)

print("roc_score_train :", roc_score_train)
print("roc_score_test :", roc_score_test)
# Out:
# roc_score_train : 0.8498373563780033
# roc_score_test : 0.8379520365435859

# %%
from sklearn.metrics import roc_curve
def roc_curve_plot(y_test , pred_proba_c1):
    # Transfer FPR and TPR based on the number of threshold
    #Draw the ROC cuve and dignoal line on the graph
    fprs , tprs , thresholds = roc_curve(y_test ,pred_proba_c1)

    plt.plot(fprs , tprs, label='ROC')
    plt.plot([0, 1], [0, 1], 'k--', label='Random', color='red')

    # Change the X-axis scale of the FPR to 0.1 units and set the X and Y-axis names. Why? -->
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1),2))
    plt.xlim(0,1)
    plt.ylim(0,1)
    plt.xlabel('FPR( 1 - Sensitivity )')
    plt.ylabel('TPR( Recall )')
    plt.legend()
    plt.show()

# %%
roc_curve_plot(y_train, y_pred_train_proba)

# %% [markdown]
# ### Feature Importances
# ---

# %%
# tranform binary feature into 0 and 1
df['Attrition'] = df['Attrition'].map({'Yes': 1, 'No': 0})
df['OverTime'] = df['OverTime'].map({'Yes': 1, 'No': 0})

# %%
# check correlation between numerical features and target variable
corr_score = df[['Age', 'DailyRate', 'DistanceFromHome', 'Education',
        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition']].corr()
corr_score
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# MonthlyIncome             0.497855   0.007707         -0.017014   0.094961
# MonthlyRate               0.028051  -0.032182          0.027473  -0.026084
# ...

# %%
# visualization of correlation relationships Heatmap
plt.figure(figsize=(15, 10))
mask = np.triu(corr_score)
sns.heatmap(corr_score,cmap="Oranges",annot = True, fmt = '.2f',mask = mask)
plt.tight_layout()
plt.savefig('corr.png');

# %% [markdown]
# > Insight
# ---
# * Regarding the correlation between Monthly Income and Job Level being 0.95, and the correlation between Total Working Years and Job Level being 0.78, as well as the correlation between Monthly Income and Total Working Years being 0.77, these could be important factors for further analysis.

# %%
plt.style.use(['dark_background'])

ftr_importances_values = rfc.feature_importances_
ftr_importances = pd.Series(ftr_importances_values, index=x_train.columns)
ftr_top20 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8, 6))
plt.title('TOP 20 Feature Importances')
sns.barplot(x=ftr_top20, y=ftr_top20.index)

for index, value in enumerate(ftr_top20):
    plt.text(value, index, f'{value:.4f}', va='center')

plt.show()

# %% [markdown]
# >Insight
# ---
# - Although the highest feature importances being around 0.1234 might seem relatively low, it doesn't automatically make the results less credible.
# - To assess the credibility of the feature importances,consider the factors mentioned above, and use them as a starting point for further analysis and interpretation

# %%
# The most noticeable variable is 'Monthlyincome' based on the model
sns.distplot(df['TotalWorkingYears']);
plt.gcf().set_size_inches(5 ,5)

# %%
ax = sns.histplot(df['TotalWorkingYears'], bins=10, kde=False)  # use histplot instead of distplot
plt.gcf().set_size_inches(5, 5)

heights, bins = np.histogram(df['TotalWorkingYears'], bins=10)
bin_centers = 0.5 * (bins[:-1] + bins[1:])

for height, x in zip(heights, bin_centers):
    ax.text(x, height + 5, int(height), ha='center', va='bottom', fontsize=8)

plt.show()

# %% [markdown]
# > Insight
# ---
# One of the most crucial periods for Company A to monitor and retain employees is when their TotalWorkingYears range from 5 to 10. These years are particularly significant.

# %%
#Binning
df['TotalWorkingYears_gp'] = np.where (df['TotalWorkingYears'] <= 10, 'Below10',
                           np.where(df['TotalWorkingYears'] <= 20, 'Between10-20', 'Over20'))

df[['TotalWorkingYears','TotalWorkingYears_gp']]
# Out:
#       TotalWorkingYears TotalWorkingYears_gp
# 0                     8              Below10
# 1                    10              Below10
# 2                     7              Below10
# 3                     8              Below10
# 4                     6              Below10
# ...                 ...                  ...
# 1465                 17         Between10-20
# 1466                  9              Below10
# 1467                  6              Below10
# 1468                 17         Between10-20
# 1469                  6              Below10
#
# [1470 rows x 2 columns]

# %%
import numpy as np
from google.colab import autoviz

def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
    from matplotlib import pyplot as plt
    import seaborn as sns
    figsize = (8 * figscale, 4.8 * figscale)
    _, ax = plt.subplots(figsize=figsize)

    bars = df[colname].value_counts()
    plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))

    # Annotate each bar with its value
    for index, value in enumerate(bars.values):
        ax.text(value + 0.02 * max(bars.values), index, str(value), va='center', color='black', fontsize=8)

    plt.title(colname)
    ax.spines[['top', 'right',]].set_visible(False)
    return autoviz.MplChart.from_current_mpl_state()

chart = categorical_histogram(_df_15, *['TotalWorkingYears_gp'], **{})
chart
# Out:
# <img src="...">
#         <script></script>

# %% [markdown]
# >** Save and Read the Model**
# ---

# %%
import pickle
saved_model = pickle.dumps(rfc)
clf_from_pickle = pickle.loads(saved_model)

# %% [markdown]
# # 🚀Conclusion
# ---

# %% [markdown]
# **Conclusions**
#
# While the given sample data may not serve as a universal best practice for every company due to the diverse range of factors affecting each organization, it can offer valuable insights to inform decision-making for internal stakeholders. By utilizing data modeling and machine learning to test hypotheses, the data can play a significant role in providing HR professionals and business leaders with clear evidence to tackle issues effectively.
#
# **Key Insights:**
#
# - *Job Level 1 Employees*: These employees, particularly in Sales, exhibit the highest attrition. It's crucial to identify their specific challenges and address them through strategies like improved training, competitive pay, and clear career progression paths.
#
# - *Research & Development Department*: Despite lower attrition at JobLevel 1, this department has the highest overall attrition, suggesting department-specific issues requiring further investigation.
#
# - *Human Resources Department*: The high attrition at JobLevels 1 and 3 suggests potential problems within this department that warrant thorough examination.
#
# - *Higher Job Levels*: Lower attrition rates at JobLevels 4 and 5, likely due to superior benefits and pay, emphasize the need for strong retention strategies for these key talents, such as leadership development and recognition programs.
#
# - It has been determined that *Overtime, Monthly Income, and Total Working Years* are the three most crucial factors in addressing employee attrition at Company A. These features have demonstrated significant impact and relevance in predicting and understanding attrition patterns within the organization. Addressing these aspects can potentially help reduce attrition and improve overall employee retention.
#
# **Future Work**
#
# To build upon the findings and insights obtained from this analysis, there are several key areas that warrant further exploration and refinement. The future work should focus on the following aspects:
#
# 1. Model Refinement: Fine-tune the model's hyperparameters and explore other algorithms for improved predictive accuracy.
#
# 2. Incorporate Additional Data: Gather employee satisfaction surveys, performance evaluations, and exit interview feedback to capture more comprehensive attrition factors.
#
# 3. Department-Specific Analysis: Conduct targeted analyses for each department to identify specific challenges and tailor strategies accordingly
